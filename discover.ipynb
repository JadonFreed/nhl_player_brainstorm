# %%
import pandas as pd

# %%
skaters = pd.read_csv("data/skaters.csv")

# %%
skaters[skaters["situation"] == "all"].head()
# Out:
#     playerId  season             name team position situation  games_played  \
# 1    8478047    2024  Michael Bunting  NSH        L       all            76
# 6    8480950    2024  Ilya Lyubushkin  DAL        D       all            80
# 11   8477369    2024     Carson Soucy  NYR        D       all            75
# 16   8481518    2024      Nolan Foote  NJD        L       all             7
# 21   8477964    2024   Ivan Barbashev  VGK        C       all            70
#
#     icetime  shifts  gameScore  ...  OffIce_F_xGoals  OffIce_A_xGoals  \
# 1   70819.0  1474.0      43.70  ...           161.54           187.75
# 6   83457.0  1763.0      10.38  ...           203.99           166.76
# 11  80618.0  1872.0       8.07  ...           159.15           151.54
# 16   4126.0   102.0       1.92  ...            20.90            17.22
# 21  70553.0  1338.0      49.58  ...           167.75           145.30
#
#     OffIce_F_shotAttempts  OffIce_A_shotAttempts  xGoalsForAfterShifts  \
# ...

# %%
skaters['position'].unique()
# Out:
# array(['L', 'D', 'R', 'C'], dtype=object)

# %%
# make player rating separated by offense and defense for now


# scoring : goals, assists, points per 60

# possession: corsi, fenwick, xgf%

# defense: xGA/60, blocks, takeaways

# discipline penalties drawn/taken

# usage: TOI, PP/PK mins, Qoc (qual of comp)

# %%
outputcsv =skaters.head(50)
outputcsv.to_csv("skaters_head50.csv")
